# %% [markdown]
# # Scape gas price data from website using Python
#
# ## 1. Gasoline Tax data
#
# This notebook is for scaping data from website. Data is rarely available in the work we want it. Sometime it's hidden within the depths of the internet and need scaping from websites.
#
# I am using https://igentax.com/gas-tax-state/#table link for scraping gas tax data.

# %%
# Import libraries 

from urllib.request import Request
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Extract table
url="https://igentax.com/gas-tax-state/#table"
raw_request = Request(url)
raw_request.add_header('User-Agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0')
raw_request.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8')
resp = urlopen(raw_request)
raw_html = resp.read()
soup = BeautifulSoup(raw_html, 'html.parser')
table1 = soup.find('table')

# %%
# Obtain every title of columns with tag <th>
headers = []
for i in table1.find_all('th'):
    title = i.text.strip()
    headers.append(title)

mydata = pd.DataFrame(columns = headers)

# Create a for loop to fill mydata
for j in table1.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [i.text.strip() for i in row_data]
    length = len(mydata)
    mydata.loc[length] = row
    
mydata
# Out:
#                    State                     Gasoline Tax  \
# 0                Alabama                   $0.28 / gallon
# 1                 Alaska                 $0.0895 / gallon
# 2                Arizona                   $0.18 / gallon
# 3               Arkansas                  $0.245 / gallon
# 4             California                  $0.511 / gallon
# 5               Colorado                   $0.22 / gallon
# 6            Connecticut                $0.25 / gallon***
# 7               Delaware                   $0.23 / gallon
# 8   District of Columbia                  $0.235 / gallon
# 9                Florida                   $0.19 / gallon
# 10               Georgia                  $0.291 / gallon
# 11                Hawaii                   $0.16 / gallon
# 12                 Idaho                    $0.32/ gallon
# 13              Illinois                   $0.392/ gallon
# 14               Indiana                   $0.32 / gallon
# 15                  Iowa  between $0.24 - $0.305 / gallon
# 16                Kansas                  $0.240 / gallon
# 17              Kentucky                  $0.246 / gallon
# 18             Louisiana                   $0.20 / gallon
# 19                 Maine                   $0.30 / gallon
# 20              Maryland                 $0.3610 / gallon
# 21         Massachusetts                   $0.24 / gallon
# 22              Michigan                  $0.272 / gallon
# 23             Minnesota                  $0.285 / gallon
# 24           Mississippi                   $0.18 / gallon
# 25              Missouri                  $0.195 / gallon
# 26               Montana                  $0.325 / gallon
# 27              Nebraska                  $0.248 / gallon
# 28                Nevada                   $0.23 / gallon
# 29         New Hampshire                  $0.222 / gallon
# 30            New Jersey                 $0.421 / gallon*
# 31            New Mexico                    $0.17/ gallon
# 32              New York                $0.2535/ gallon**
# 33        North Carolina                  $0.385 / gallon
# 34          North Dakota                  $0.230 / gallon
# 35                Ohio**                  $0.385 / gallon
# 36              Oklahoma                   $0.19 / gallon
# 37                Oregon                   $0.38 / gallon
# 38          Pennsylvania                  $0.576 / gallon
# 39          Rhode Island                   $0.34 / gallon
# 40        South Carolina                   $0.26 / gallon
# 41          South Dakota                   $0.28 / gallon
# 42             Tennessee                   $0.26 / gallon
# 43                 Texas                   $0.20 / gallon
# 44                  Utah                  $0.319 / gallon
# 45               Vermont                  $0.316 / gallon
# 46              Virginia                   $0.262/ gallon
# 47            Washington                  $0.494 / gallon
# 48         West Virginia                  $0.357 / gallon
# 49             Wisconsin                  $0.309 / gallon
# 50               Wyoming                   $0.24 / gallon
#
#                   Undyed Diesel Tax  \
# 0                    $0.29 / gallon
# 1                  $0.0895 / gallon
# 2            $0.18 or $0.26/ gallon
# 3                   $0.285 / gallon
# 4                   $0.389 / gallon
# 5                   $0.205 / gallon
# 6                $0.401 / gallon***
# 7                    $0.22 / gallon
# 8                   $0.235 / gallon
# 9                    $0.19 / gallon
# 10                  $0.326 / gallon
# 11                   $0.16 / gallon
# 12                   $0.32 / gallon
# 13                  $0.467 / gallon
# 14                   $0.53 / gallon
# 15    between $0.304 -0.325/ gallon
# 16                  $0.260 / gallon
# 17                  $0.216 / gallon
# 18                   $0.20 / gallon
# 19                  $0.312 / gallon
# 20                 $0.3685 / gallon
# 21                   $0.24 / gallon
# 22                  $0.272 / gallon
# 23                  $0.285 / gallon
# 24                   $0.18 / gallon
# 25                  $0.195 / gallon
# 26                 $0.2955 / gallon
# 27                  $0.248 / gallon
# 28                   $0.27 / gallon
# 29                  $0.222 / gallon
# 30                  $0.494/ gallon*
# 31                    $0.21/ gallon
# 32  between $23.7 - $0.253 / gallon
# 33                  $0.385 / gallon
# 34                  $0.230 / gallon
# 35                   $0.47 / gallon
# 36                   $0.16 / gallon
# 37                   $0.38 / gallon
# 38                  $0.741 / gallon
# 39                   $0.34 / gallon
# 40                   $0.26 / gallon
# 41                   $0.28 / gallon
# 42                   $0.27 / gallon
# 43                   $0.20 / gallon
# 44                  $0.319 / gallon
# 45                  $0.341 / gallon
# 46                   $0.27 / gallon
# 47                  $0.494 / gallon
# 48                  $0.357 / gallon
# 49                  $0.309 / gallon
# 50                   $0.24 / gallon
#
#                              Aviation Fuel Tax  \
# 0                              $0.095 / gallon
# 1                              $0.047 / gallon
# 2                               $0.05 / gallon
# 3                                       no tax
# 4                               $0.18 / gallon
# 5                               $0.06 / gallon
# 6   8.1% petroleum products gross earnings tax
# 7                               $0.23 / gallon
# 8                              $0.235 / gallon
# 9                             $0.0427 / gallon
# 10                              $0.01 / gallon
# 11                              $0.01 / gallon
# 12                              $0.07 / gallon
# 13                                      no tax
# 14                             varies by class
# 15                              $0.08 / gallon
# 16                                      no tax
# 17                                      no tax
# 18                              $0.20 / gallon
# 19                              $0.30 / gallon
# 20                             $0.070 / gallon
# 21                             $0.308 / gallon
# 22                              $0.03 / gallon
# 23                              $0.05 / gallon
# 24                             $0.064 / gallon
# 25                              $0.09 / gallon
# 26                              $0.05 / gallon
# 27                             $0.050 / gallon
# 28                              $0.02 / gallon
# 29                              $0.04 / gallon
# 30                             $0.165 / gallon
# 31                              $0.17 / gallon
# 32           between $0.070 - $0.0173 / gallon
# 33                                      no tax
# 34                              $0.08 / gallon
# 35                                      no tax
# 36                            $0.0008 / gallon
# 37                              $0.11 / gallon
# 38                              $0.06 / gallon
# 39                                      no tax
# 40                                      no tax
# 41                              $0.06 / gallon
# 42                                      no tax
# 43                              $0.20 / gallon
# 44            between $0.025 - $0.090 / gallon
# 45                            $0.3073 / gallon
# 46                              $0.05 / gallon
# 47                              $0.11 / gallon
# 48                             $0.152 / gallon
# 49                              $0.06 / gallon
# 50                              $0.05 / gallon
#
#                                   Jet Fuel Tax
# 0                              $0.035 / gallon
# 1                              $0.032 / gallon
# 2           $0.035 / on 1st 10 million gallons
# 3                                       no tax
# 4                               $0.02 / gallon
# 5                               $0.04 / gallon
# 6   8.1% petroleum products gross earnings tax
# 7                               $0.05 / gallon
# 8                              $0.235 / gallon
# 9                             $0.0427 / gallon
# 10                   no tax with a Form MFD-03
# 11                              $0.01 / gallon
# 12                              $0.06 / gallon
# 13                                      no tax
# 14                             varies by class
# 15                              $0.05 / gallon
# 16                                      no tax
# 17                                      no tax
# 18                              $0.20 / gallon
# 19                             $0.034 / gallon
# 20                             $0.070 / gallon
# 21                             $0.114 / gallon
# 22                              $0.03 / gallon
# 23                              $0.15 / gallon
# 24                            $0.0525 / gallon
# 25                                      no tax
# 26                              $0.05 / gallon
# 27                             $0.030 / gallon
# 28                              $0.01 / gallon
# 29             between $0.02 - $0.005 / gallon
# 30                             $0.195 / gallon
# 31                                      no tax
# 32                             $0.070 / gallon
# 33                                      no tax
# 34                              $0.08 / gallon
# 35                                      no tax
# 36                            $0.0008 / gallon
# 37                              $0.03 / gallon
# 38                              $0.02 / gallon
# 39                                      no tax
# 40                                      no tax
# 41                              $0.04 / gallon
# 42                                      no tax
# 43                              $0.20 / gallon
# 44            between $0.025 - $0.090 / gallon
# 45                                      no tax
# 46                              $0.05 / gallon
# 47                              $0.11 / gallon
# 48                             $0.152 / gallon
# 49                              $0.06 / gallon
# 50                              $0.05 / gallon

# %%
# Clean table 

df = mydata[['State','Gasoline Tax']]
df['Gasoline Tax'] = df['Gasoline Tax'].str.replace("$",'')
df['Gasoline Tax'] = df['Gasoline Tax'].str.replace("/ gallon",'')
df['Gasoline Tax'] = df['Gasoline Tax'].str.replace("*",'')
df['State'] = df['State'].str.replace("*",'')


# Replace a textual string with average of values in the string
df.loc[df['State']=='Iowa','Gasoline Tax'] = 0.273
df.columns = ['State','Gas_Tax']
# Out:
# /home/mouse/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/mouse/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/mouse/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/mouse/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/mouse/miniconda3/envs/ml/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /home/mouse/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Save to csv 

df.to_csv('data/state_gastax.csv')

# %% [markdown]
# ## 2. Average gas price state wise in USA
#
# This data is scaped from https://www.gasbuddy.com/usa website on May 28, 2022. Gas prices keep fluctuating so if you run these line of code, you might end up with a table with different data.

# %%
# Extract table
url="https://www.gasbuddy.com/usa"
raw_request = Request(url)
raw_request.add_header('User-Agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0')
raw_request.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8')
resp = urlopen(raw_request)
raw_html = resp.read()
soup = BeautifulSoup(raw_html, 'html.parser')
table1 = soup.find('searchItems')
print(table1)
# Out:
# None

# %%
# Extract state and rate data from soup data

col1 = []
col2 = []

# Extract state values
table1 = soup.find_all('div', attrs={'class':'col-sm-6 col-xs-6 siteName'})
for row in table1:
    col1.append(row.get_text().strip())

# Extract rate data
table2 = soup.find_all('div', attrs={'class':'col-sm-2 col-xs-3 text-right'})
for row in table2:
    col2.append(row.get_text().strip())

# Create dataframe from list
df_rate = pd.DataFrame(list(zip(col1,col2)),columns = ['State','Rate'])
df_rate
# Out:
#              State   Rate
# 0         Oklahoma  4.095
# 1          Georgia  4.111
# 2         Arkansas  4.116
# 3           Kansas  4.123
# 4      Mississippi  4.155
# 5        Louisiana  4.195
# 6     South Dakota  4.199
# 7         Missouri  4.209
# 8         Nebraska  4.209
# 9   South Carolina  4.217
# 10           Texas  4.229
# 11        Colorado  4.235
# 12       Minnesota  4.238
# 13    North Dakota  4.248
# 14       Tennessee  4.255
# 15            Iowa  4.272
# 16      New Mexico  4.286
# 17         Alabama  4.287
# 18        Kentucky  4.307
# 19         Wyoming  4.315
# 20  North Carolina  4.342
# 21       Wisconsin  4.388
# 22         Montana  4.406
# 23            Ohio  4.443
# 24        Virginia  4.456
# 25   West Virginia  4.458
# 26         Florida  4.561
# 27        Michigan  4.567
# 28         Indiana  4.576
# 29        Maryland  4.576
# 30        Delaware  4.588
# 31        San Juan  4.602
# 32     Connecticut  4.654
# 33   New Hampshire  4.673
# 34            Utah  4.679
# 35    Rhode Island  4.697
# 36           Idaho  4.712
# 37   Massachusetts  4.713
# 38         Vermont  4.715
# 39      New Jersey  4.731
# 40    Pennsylvania  4.754
# 41           Maine  4.761
# 42   Washington DC  4.839
# 43        New York  4.901
# 44         Arizona  4.960
# 45        Illinois  4.977
# 46          Oregon  5.176
# 47          Alaska  5.184
# 48      Washington  5.213
# 49          Nevada  5.234
# 50          Hawaii  5.412
# 51      California  6.119

# %%
df_rate.to_csv('data/state_gasrate.csv')
